# %% [markdown]
# Initialize Spark with Iceberg + MinIO + REST catalog

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("CDC-Bronze")
    .config("spark.sql.catalog.lakehouse", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.lakehouse.type", "rest")
    .config("spark.sql.catalog.lakehouse.uri", "http://iceberg-rest:8181")
    .config("spark.sql.catalog.lakehouse.io-impl", "org.apache.iceberg.aws.s3.S3FileIO")
    .config("spark.sql.catalog.lakehouse.s3.endpoint", "http://minio:9000")
    .config("spark.sql.catalog.lakehouse.s3.path-style-access", "true")
    .config("spark.sql.defaultCatalog", "lakehouse")
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[1], line 13
#       1 from pyspark.sql import SparkSession
#       3 spark = (
#       4     SparkSession.builder
#       5     .appName("CDC-Bronze")
#       6     .config("spark.sql.catalog.lakehouse", "org.apache.iceberg.spark.SparkCatalog")
#       7     .config("spark.sql.catalog.lakehouse.type", "rest")
#       8     .config("spark.sql.catalog.lakehouse.uri", "http://iceberg-rest:8181")
#       9     .config("spark.sql.catalog.lakehouse.io-impl", "org.apache.iceberg.aws.s3.S3FileIO")
#      10     .config("spark.sql.catalog.lakehouse.s3.endpoint", "http://minio:9000")
#      11     .config("spark.sql.catalog.lakehouse.s3.path-style-access", "true")
#      12     .config("spark.sql.defaultCatalog", "lakehouse")
# ---> 13     .getOrCreate()
#      14 )
#
# File /usr/local/spark/python/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File /usr/local/spark/python/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File /usr/local/spark/python/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File /usr/local/spark/python/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File /usr/local/spark/python/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %% [markdown]
# Create the namespace

# %%
spark.sql("CREATE NAMESPACE IF NOT EXISTS lakehouse.cdc")

# %% [markdown]
# Read CDC events from Kafka

# %%
raw = (
    spark.read
    .format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "dbserver1.public.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %% [markdown]
# Parse the Debezium envelope

# %%
from pyspark.sql import functions as F

raw_filtered = raw.filter(F.col("value").isNotNull())

bronze_df = raw_filtered.select(
    F.col("topic"),
    F.col("partition").alias("kafka_partition"),
    F.col("offset").alias("kafka_offset"),
    F.col("timestamp").alias("kafka_timestamp"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.op").alias("op"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.ts_ms").cast("long").alias("ts_ms"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.after.id").cast("int").alias("after_id"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.after.name").alias("after_name"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.after.email").alias("after_email"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.after.country").alias("after_country"),
    F.get_json_object(F.col("value").cast("string"), "$.payload.before.id").cast("int").alias("before_id"),
)

# %%
#Can preview
bronze_df.show(5, truncate=False)

# %% [markdown]
# Write to Bronze Iceberg table

# %%
bronze_df.writeTo("lakehouse.cdc.bronze_customers").createOrReplace()

# %%
Later use this (append)

# %%
#bronze_df.writeTo("lakehouse.cdc.bronze_customers").append()

# %%
Verify the Bronze table - count rows and sample rows

# %%
spark.sql("SELECT count(*) FROM lakehouse.cdc.bronze_customers").show()

# %%
spark.sql("""
  SELECT op, after_id, after_name, after_email, ts_ms
  FROM lakehouse.cdc.bronze_customers
  LIMIT 5
""").show(truncate=False)
